# %%
import pandas

from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
#pravim tabele za broj koji koriste odredjena droga u 2013-2017
def fali(dic):
    for key,value in dic.items():
        if(value)==0:
            return True
    return False
def missing(dic):
    if(dic):
        vrednosti=np.array([v for v in dic.values()])
        avg=np.sum(vrednosti)/len(vrednosti)
        for key,value in dic.items():
            if value==0:
                dic[key]=avg
def tabela(fajl,tab):
    c=pandas.read_excel(fajl)
    godine=[v for v in tab.keys()]
    for i,row in c.iterrows():
        if not np.isnan(row["Sample size"]) and not np.isnan(row["Year"]) and not np.isnan(row["Total"]) and row["Year"] in godine:
            sample=row["Sample size"]
            tot=row["Total"]/100
            broj=sample*tot
            god=row["Year"]
            tab[int(god)]+=broj
    missing(tab)
    t=[v for v in tab.values()]
    return t
#znam da je spaghetti ali nisam mogao sa for loopom da uradim probao sam
alkk={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
kann={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
tobb={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
amm={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
cocc={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
lss={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
ecss={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
al=tabela("./tables/prevalance/alcohol.xlsx",alkk)
am=tabela("./tables/prevalance/amph.xlsx",amm)
can=tabela("./tables/prevalance/cannabis.xlsx",kann)
coc=tabela("./tables/prevalance/cocaine.xlsx",cocc)
ls=tabela("./tables/prevalance/lsd.xlsx",lss)
ecs=tabela("./tables/prevalance/ecstasy.xlsx",ecss)
tob=tabela("./tables/prevalance/tobacco.xlsx",tobb)
godine=[g for g in range(2010,2018)]
godine2=[g for g in range(2010,2017)]

labels=["Alcohol","Cannabis","Tobacco"]
plt.figure(figsize=(15,7))
plt.stackplot(godine, al, can, tob, labels=labels)
plt.legend(loc='upper left')
plt.xlabel("Year",fontsize=15)
plt.ylabel("Number of users",fontsize=15)
plt.title("Prevalance of the most common opiates in Europe",fontsize=25)
plt.show()

# %%
plt.figure(figsize=(15,7))
labels=["Cocaine","LSD","Ecstasy","Amphetamine"]
plt.figure(figsize=(15,7))
plt.stackplot(godine2, coc, ls, ecs,am, labels=labels)
plt.legend(loc='upper left')
plt.xlabel("Year",fontsize=15)
plt.ylabel("Number of users",fontsize=15)
plt.title("Prevalance of hard drugs in Europe",fontsize=25)
plt.show()

# %%
tabele=[am,can,coc,ls,ecs]
ukupno={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
for i in range(0,7):
    for tab in tabele:
        ukupno[i+2010]+=tab[i]
alk={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
def procenti(tab1,tab2):
    for i in range(0,7):
        tab1[i+2010]=(tab2[i]*100)/ukupno[i+2010]
    t=[v for v in tab1.values()]
    return t
di={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
di1={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
di2={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
di3={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
di4={2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0}
kan=procenti(di,can)
amf=procenti(di1,am)
koka=procenti(di2,coc)
eles=procenti(di3,ls)
kser=procenti(di4,ecs)
plt.figure(figsize=(15,7))
labels=["LSD","Amphetamine","Cocaine","Ecstasy","Cannabis"]
plt.figure(figsize=(15,7))
plt.stackplot(godine2,kan,kser,koka,amf,eles, labels=labels[::-1])
plt.legend(loc='upper left')
plt.xlabel("Year",fontsize=15)
plt.ylabel("Procentages",fontsize=15)
plt.title("Prevalance of drugs in Europe",fontsize=25)
plt.show()

# %% [markdown]
# As you can see, the percentage of people that use cannabis is way higher than the other drugs we analyze and it is a big problem in Europe.

# %%
cocaineUsers = pandas.read_excel('./tables/drugOffenses/cocaineUsers.xlsx')
cocc={2005:0,2006:0,2007:0,2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
ecc={2005:0,2006:0,2007:0,2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
cann={2005:0,2006:0,2007:0,2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
heroo={2005:0,2006:0,2007:0,2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
def popuni(tab1,file):
    f=pandas.read_excel(file)
    for i,row in f.iterrows():
        for i in range(2005,2018):
            if not np.isnan(row[i]):
                tab1[i]+=row[i]
    return tab1
kok=popuni(cocc,'./tables/drugOffenses/cocaineUsers.xlsx')
eks=popuni(ecc,'./tables/drugOffenses/ecstasyUsers.xlsx')
kan=popuni(cann,'./tables/drugOffenses/cannabisUsers.xlsx')
hero=popuni(heroo,'./tables/drugOffenses/heroinUsers.xlsx')
tabele=[kok,eks,kan,hero]
ukupno={2005:0,2006:0,2007:0,2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
for i in range(2005,2018):
    for tab in tabele:
        ukupno[i]+=tab[i]
def procenti(tab1,tab2):
    for i in range(2005,2018):
        tab1[i]=(tab2[i]*100)/ukupno[i]
    t=[v for v in tab1.values()]
    return t
t1={2005:0,2006:0,2007:0,2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
t2={2005:0,2006:0,2007:0,2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
t3={2005:0,2006:0,2007:0,2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
t4={2005:0,2006:0,2007:0,2008:0,2009:0,2010:0,2011:0,2012:0,2013:0,2014:0,2015:0,2016:0,2017:0}
kokain=procenti(t1,kok)
ekstazi=procenti(t2,eks)
kanabis=procenti(t3,kan)
heroin=procenti(t4,hero)
godine=[v for v in t1.keys()]
#kanabis heroin kokain ekstazi
plt.figure(figsize=(15,7))
labels=["Ecstasy","Cocaine","Heroin","Cannabis"]
plt.figure(figsize=(15,7))
plt.stackplot(godine,kanabis,heroin,kokain,ekstazi, labels=labels[::-1])
plt.legend(loc='upper left')
plt.xlabel("Year",fontsize=15)
plt.ylabel("Procentages",fontsize=15)
plt.title("Prevalance of drugs in Europe",fontsize=25)
plt.show()

# %%
kan
# Out:
# {2005: 337394.0,
#  2006: 357303.0,
#  2007: 554236.0,
#  2008: 646611.0,
#  2009: 715869.0,
#  2010: 688027.0,
#  2011: 678942.0,
#  2012: 664404.0,
#  2013: 667693.0,
#  2014: 671946.0,
#  2015: 627239.0,
#  2016: 646638.0,
#  2017: 634525.0}
